# %% [markdown]
# ##### How to split by HTML header
# HTMLHeaderTextSplitter is a "structure-aware" chunker that splits text at the HTML element level and adds metadata for each header "relevant" to any given chunk. It can return chunks element by element or combine elements with the same metadata, with the objectives of (a) keeping related text grouped (more or less) semantically and (b) preserving context-rich information encoded in document structures. It can be used with other text splitters as part of a chunking pipeline.

# %%
from langchain_text_splitters import HTMLHeaderTextSplitter

html_string = """
<!DOCTYPE html>
<html>
<body>
    <div>
        <h1>Foo</h1>
        <p>Some intro text about Foo.</p>
        <div>
            <h2>Bar main section</h2>
            <p>Some intro text about Bar.</p>
            <h3>Bar subsection 1</h3>
            <p>Some text about the first subtopic of Bar.</p>
            <h3>Bar subsection 2</h3>
            <p>Some text about the second subtopic of Bar.</p>
        </div>
        <div>
            <h2>Baz</h2>
            <p>Some text about Baz</p>
        </div>
        <br>
        <p>Some concluding text about Foo</p>
    </div>
</body>
</html>
"""

headers_to_split_on=[
    ("h1","Header 1"),
    ("h2","Header 2"),
    ("h3","Header 3")
]

html_splitter=HTMLHeaderTextSplitter(headers_to_split_on)
html_header_splits=html_splitter.split_text(html_string)
html_header_splits
# Out:
# [Document(metadata={'Header 1': 'Foo'}, page_content='Foo'),
#  Document(metadata={'Header 1': 'Foo'}, page_content='Some intro text about Foo.'),
#  Document(metadata={'Header 1': 'Foo', 'Header 2': 'Bar main section'}, page_content='Bar main section'),
#  Document(metadata={'Header 1': 'Foo', 'Header 2': 'Bar main section'}, page_content='Some intro text about Bar.'),
#  Document(metadata={'Header 1': 'Foo', 'Header 2': 'Bar main section', 'Header 3': 'Bar subsection 1'}, page_content='Bar subsection 1'),
#  Document(metadata={'Header 1': 'Foo', 'Header 2': 'Bar main section', 'Header 3': 'Bar subsection 1'}, page_content='Some text about the first subtopic of Bar.'),
#  Document(metadata={'Header 1': 'Foo', 'Header 2': 'Bar main section', 'Header 3': 'Bar subsection 2'}, page_content='Bar subsection 2'),
#  Document(metadata={'Header 1': 'Foo', 'Header 2': 'Bar main section', 'Header 3': 'Bar subsection 2'}, page_content='Some text about the second subtopic of Bar.'),
#  Document(metadata={'Header 1': 'Foo', 'Header 2': 'Baz'}, page_content='Baz'),
#  Document(metadata={'Header 1': 'Foo'}, page_content='Some text about Baz  \nSome concluding text about Foo')]

# %%
url = "https://www.comsats.edu.pk/"

headers_to_split_on = [
    ("h1", "Header 1"),
    ("h2", "Header 2"),
    ("h3", "Header 3"),
    ("h4", "Header 4"),
]
html_splitter = HTMLHeaderTextSplitter(headers_to_split_on)
html_header_splits = html_splitter.split_text_from_url(url)
html_header_splits
# Out:
# [Document(metadata={}, page_content='<div id="preloader"></div> Vendor JS Files <script src="assets/vendor/php-email-form/validate.js"></script> Template Main JS File Jarallax JS Jarallax JS: Optional video extension Modal JS Script The Modal  \nModal  \n======= Hero Section ======= End Hero End #main ======= Footer ======= End Footer  \n<h1 class="logo me-auto me-lg-0"><a href="index.html">Gp<span>.</span></a></h1> Uncomment below if you prefer to use an image logo .navbar  \nCOMSATS University Islamabad  \n<i class="bi bi-list mobile-nav-toggle"></i>  \nNews  \nCampuses  \nAcademic Programs  \nAdmissions  \nStudents  \nResearch  \nAlumni  \nAbout'),
#  Document(metadata={'Header 1': 'COMSATS University'}, page_content='COMSATS University'),
#  Document(metadata={'Header 1': 'COMSATS University'}, page_content="Islamabad  \nCOMSATS University Islamabad (CUI) started its journey in 1998, and established its first campus at Islamabad in April 1998. In August 2000, in recognition of CUI's achievements, the Federal Government granted it the status of a Degree Awarding Institute (DAI) through promulgation of its charter.  \nRead More"),
#  Document(metadata={'Header 1': 'COMSATS University', 'Header 4': 'Islamabad Campus'}, page_content='Islamabad Campus'),
#  Document(metadata={'Header 1': 'COMSATS University', 'Header 4': 'Islamabad Campus'}, page_content='Website'),
#  Document(metadata={'Header 1': 'COMSATS University', 'Header 4': 'Abbottabad Campus'}, page_content='Abbottabad Campus'),
#  Document(metadata={'Header 1': 'COMSATS University', 'Header 4': 'Abbottabad Campus'}, page_content='Website'),
#  Document(metadata={'Header 1': 'COMSATS University', 'Header 4': 'Lahore Campus'}, page_content='Lahore Campus'),
#  Document(metadata={'Header 1': 'COMSATS University', 'Header 4': 'Lahore Campus'}, page_content='Website'),
#  Document(metadata={'Header 1': 'COMSATS University', 'Header 4': 'Wah Campus'}, page_content='Wah Campus'),
#  Document(metadata={'Header 1': 'COMSATS University', 'Header 4': 'Wah Campus'}, page_content='Website'),
#  Document(metadata={'Header 1': 'COMSATS University', 'Header 4': 'Attock Campus'}, page_content='Attock Campus'),
#  Document(metadata={'Header 1': 'COMSATS University', 'Header 4': 'Attock Campus'}, page_content='Website'),
#  Document(metadata={'Header 1': 'COMSATS University', 'Header 4': 'Sahiwal Campus'}, page_content='Sahiwal Campus'),
#  Document(metadata={'Header 1': 'COMSATS University', 'Header 4': 'Sahiwal Campus'}, page_content='Website'),
#  Document(metadata={'Header 1': 'COMSATS University', 'Header 4': 'Vehari Campus'}, page_content='Vehari Campus'),
#  Document(metadata={'Header 1': 'COMSATS University', 'Header 4': 'Vehari Campus'}, page_content='Website'),
#  Document(metadata={'Header 1': 'COMSATS University', 'Header 4': 'Virtual Campus'}, page_content='Virtual Campus'),
#  Document(metadata={}, page_content='Website  \nCOMSATS  \nExplore  \n======= Team Section ======= End Team Section ======= Admissions Section ======= End Team Section ======= Cta Section ======= End Cta Section ======= Academics Section ======= End Academics Section ======= About Section ======= <section id="slide1" class="intro bg-dark-subtle pb-5 pt-5 text-center text-lg-start">\r\n        <div class="container pb-4 pt-4">\r\n            <div class="align-items-center pb-5 pt-5 row ">\r\n                <div class="col-lg-5 ms-0 ms-lg-n2 ms-sm-0 order-lg-2 pb-3 pb-lg-3 pb-sm-3 pt-3 pt-lg-3 pt-sm-3 text-center ">\r\n                    <img src="assets/img/Inchage-campus.jpg" class="intro-img img-fluid shadow mb-2 position-relative" alt="Professor Sohail Asghar (PhD)">\r\n                    <span class="h4 fw-bold">Professor Sohail Asghar (PhD)</span>\r\n                </div>\r\n                <div class="col-lg-7 pb-3 pt-3">\r\n                    <div class="bg-primary me-0 me-lg-n5 me-sm-0 p-5 p-lg-5 p-sm-5 text-white-50 position-relative">\r\n                        <h2 class="fw-bold text-white">Message by the InCharge</h2>\r\n                        <p class="fst-italic text-info">Dear students and faculty,</p>\r\n                        <p>I hope this message finds you in good health and high spirits. It is my distinct privilege and utmost enthusiasm to address you in my capacity as the InCharge of the Islamabad Campus at COMSATS University Islamabad.</p>\r\n                        <p>COMSATS University has always consistently upheld its reputation as a paragon of excellence in the realms of education, research, and innovation, and it&apos;s because of each one of you that we maintain this tradition of excellence.</p>\r\n                        <p>I wish to convey that your presence in this capital campus is of paramount importance to us. We, as a collective team, are unwavering in our commitment to furnish you with the highest caliber of education encompassing various domains, including the Sciences, Social Sciences, and Emerging Technologies. Our comprehensive pedagogical approach, encompassing both in-person and a blend of hybrid learning modules, has been meticulously crafted to endow you with a comprehensive and enriching educational experience, underpinned by cutting-edge curricula tailored to the distinct disciplines.</p>\r\n                        <p><a href="" class="btn btn-info">Read More</a></p>\r\n                    </div>\r\n                </div>\r\n            </div>\r\n        </div>\r\n    </section> End About Section ======= Clients Section ======= <section id="clients" class="clients">\r\n        <div class="container" data-aos="zoom-in">\r\n            <div class="clients-slider swiper">\r\n                <div class="swiper-wrapper align-items-center">\r\n                    <div class="swiper-slide">\r\n                        <img src="assets/img/clients/client-1.png" class="img-fluid" alt="">\r\n                    </div>\r\n                    <div class="swiper-slide">\r\n                        <img src="assets/img/clients/client-2.png" class="img-fluid" alt="">\r\n                    </div>\r\n                    <div class="swiper-slide">\r\n                        <img src="assets/img/clients/client-3.png" class="img-fluid" alt="">\r\n                    </div>\r\n                    <div class="swiper-slide">\r\n                        <img src="assets/img/clients/client-4.png" class="img-fluid" alt="">\r\n                    </div>\r\n                    <div class="swiper-slide">\r\n                        <img src="assets/img/clients/client-5.png" class="img-fluid" alt="">\r\n                    </div>\r\n                    <div class="swiper-slide">\r\n                        <img src="assets/img/clients/client-6.png" class="img-fluid" alt="">\r\n                    </div>\r\n                    <div class="swiper-slide">\r\n                        <img src="assets/img/clients/ ...
#  Document(metadata={'Header 4': 'Statutory Information'}, page_content='Statutory Information'),
#  Document(metadata={'Header 4': 'Statutory Information'}, page_content='CUI  \nLearn More  \nCUI Act - 2018  \nRules of Business of the Meetings of CUI Authorities - 2018  \nStatutes of the Authorities, Committees, Principal Officers, and Teachers of CUI - 2019  \nStatutes for Affiliation and Disaffiliation of Education Institutions and Related Matters of COMSATS University Islamabad – 2024'),
#  Document(metadata={'Header 4': 'of Education Institutions'}, page_content='of Education Institutions'),
#  Document(metadata={'Header 4': 'of Education Institutions'}, page_content='Affiliation and Disaffiliation  \nLearn More'),
#  Document(metadata={'Header 4': 'University Teachers'}, page_content='University Teachers'),
#  Document(metadata={'Header 4': 'University Teachers'}, page_content='Election for  \nLearn More'),
#  Document(metadata={'Header 4': 'Complaint Cell'}, page_content='Complaint Cell'),
#  Document(metadata={'Header 4': 'Complaint Cell'}, page_content='CUI  \nLearn More  \nPensioners Complaint Cell  \nOnline Complaint Registration  \nCheck Complaint Status'),
#  Document(metadata={'Header 4': 'Sustainable Development Goals'}, page_content='Sustainable Development Goals'),
#  Document(metadata={}, page_content='SDGs 2030  \nLearn More  \nAdmissions  \nUndergraduate Admissions  \nInformation related to Undergraduate Admissions  \nLearn More  \nGraduate Admissions  \nInformation related to Graduate Admissions  \nLearn More  \nPhD Programs  \nInformation related to PhD Admissions  \nLearn More  \nFee Structure  \nInformation related to Fee Structure  \nLearn More  \nHow to Apply?  \nAdmission procedure in 12 easy steps  \nLearn More  \nApply Now!  \nApply now by visiting the admissions website  \nLearn More  \nMore About Admissions'),
#  Document(metadata={'Header 3': 'Message by the Rector'}, page_content='Message by the Rector'),
#  Document(metadata={'Header 3': 'Message by the Rector', 'Header 4': 'Prof. Dr. Sajid Qamar'}, page_content='Prof. Dr. Sajid Qamar'),
#  Document(metadata={}, page_content='I feel honored to lead the COMSATS University Islamabad (CUI) as Rector and share with you my vision for CUI, which has always been an innovative institution of learning and development...  \nRead More  \nUpcoming Events  \nCareer Expo Spring 2024  \nCOMSATS Industrial Connect - Career Expo Spring 2024  \n15 May, 2024  \nRead More  \nPEEF Scholarship - Announcement  \nCUI, Islamabad campus announces PEEF Scholarship for Masters 2023-24  \n30 April, 2024  \nRead More  \nStudent Startup Business Center - Batch - 12  \nEnrollment of Startup batch 12 at Student Startup Business Center - SSBC  \n24 April, 2024  \nRead More  \nTwo-Day International Conference  \nTwo-Day International Conference on Solar Radiation Modification  \n3-4 Jan, 2024  \nRead More  \nCOMSATS EAT Fest Season 4  \nCOMSATS EAT Fest Season 4 - Food Stall / Activities - 18-19 December, 2023  \n18-19 Dec, 2023  \nRead More  \nFinancing of Final Year Design Projects  \nFinancing of Final Year Design Projects (2023-24)  \n3-4 Jan, 2024  \nRead More  \nHult Prize COMSATS University Islamabad  \nHult Prize COMSATS University Islamabad  \n4 Mar, 2024  \nRead More  \nMore Events  \nCampuses  \nDegree Programs  \nEnrolled Students  \nPhd Students  \nMS Students  \nUnder Graduates  \nInterdisciplinary Science  \nNature Index'),
#  Document(metadata={'Header 3': 'COMSATS University Islamabad'}, page_content='COMSATS University Islamabad'),
#  Document(metadata={'Header 3': 'COMSATS University Islamabad'}, page_content="The COMSATS University Islamabad, founded in the belief that understanding enriches all people, is dedicated to the search for truth through advancement of learning and extending the frontiers of knowledge; to the sharing of this knowledge through education in an academically diverse range of disciplines and subjects; and to the application of this knowledge to benefit the people of Pakistan, the Muslim Ummah, and the World, at large. The University's mission is threefold:  \nResearch and Discovery  \nTeaching and Learning  \nOutreach and Public Service  \nThe COMSATS University Islamabad envisions assuming a truly national character for itself in the years to come. It envisions having presence in all provinces of the country. It sees for itself a position among the top five (5) universities in the country; among top 100 universities in the developing countries and top 300, 200, 100 universities in the world respectively in the 5, 10 and 15-years’ time horizon.  \nRead More"),
#  Document(metadata={'Header 3': 'Office of Research, Innovation and Commercialization (ORIC)'}, page_content='Office of Research, Innovation and Commercialization (ORIC)'),
#  Document(metadata={'Header 3': 'Office of Research, Innovation and Commercialization (ORIC)'}, page_content='ORIC was established in 2011 with the aim of linking university research directly with educational, social and economic priorities of CUI and its broader community. Its slogan is “Creating endless opportunities by transforming research into prosperity.”  \nVisit Now!  \nWhy CUI?'),
#  Document(metadata={'Header 2': 'CUI aspires to be both one of the top research institutions and one of the best higher education providers in the country'}, page_content='CUI aspires to be both one of the top research institutions and one of the best higher education providers in the country'),
#  Document(metadata={}, page_content='Faculties & Departments  \nAt the COMSATS University Islamabad Campus, there are 5 faculties and 13 departments...  \nRead More  \nCourse Catalog  \nThe CUI Course Catalog Portal serves as a dedicated information and support platform exclusively designed for CUI Faculty & Staff...  \nRead More  \nResearch Portal  \nCheck the total number of publications uploaded by our faculty and staff members from different campuses...  \nRead More  \nInternational Students  \nInternational Admissions Unit (IAU) has been setup in International Office, to facilitate International Students...  \nRead More  \nPhd Graduates  \nBrowse and search profiles of COMSATS University Islamabad PhD Graduates...  \nRead More  \nScholarships  \nCheck the scholarships from different countries and multiple international universities....  \nRead More  \nContent Column Image Column  \n<div class="title">Islamabad Campus</div>'),
#  Document(metadata={'Header 2': 'Founder Rector,'}, page_content='Founder Rector,'),
#  Document(metadata={}, page_content='Dr. Syed Muhammad Junaid Zaidi, H.I., S.I.  \nDr. S. M. Junaid Zaidi, H.I., S.I. is the Founder Rector of the COMSATS University Islamabad (CUI), Pakistan’s first exclusive institute of information technology. The CUI was awarded Charter by the Government of Pakistan in 2000 and in less than a decade, it has grown into a quality institution of higher learning under his able leadership. CUI now has eight campuses in seven cities, a student population of more than 35,000 and faculty base of 2,887. In addition to Information Technology, the Institute offers several bachelor, master and doctoral programs in engineering, basic sciences, management sciences and architecture. Dr Zaidi’s professional experience spans 36 years in a diverse range of fields. The establishment of IT ventures and development of IT policies remains the epic highlight of his career.  \nRead More  \nDr. Syed Muhammad Junaid Zaidi, H.I., S.I.'),
#  Document(metadata={'Header 2': 'Services'}, page_content='Services'),
#  Document(metadata={'Header 2': 'Services'}, page_content='Check our Services  \nSafety First  \nYour safety is our most important concern.  \nRegular Classes  \nWe are providing regular classes to our students.  \nHighly Qualified Teachers  \nSkills in communication, listening, collaboration, adaptability, empathy and patience.  \nSufficient Classrooms  \n74 spacious lecture theatres, with a total covered area of 49,318.81sq ft. Each theatre has a capacity for 100-120 students All lecture theatres are IT enabled, air-conditioned, well furnished, and well maintained.  \nState of the art Labs  \n50 laboratories More than 1,100 computers Major Laboratories are Electronics, Microprocessor, VLSI and DSP and Biosciences laboratories.  \nSports Facilities  \nTo relieve academic pressures, sports have become an integral part of the extracurricular activities at COMSATS Islamabad.  \nTransport  \nStudents are provided transport facility on the specified routes.  \nCafeteria  \nA food-street style catering service consisting of shops and kiosks having a wide range of quality snacks and meals'),
#  Document(metadata={'Header 2': 'Services', 'Header 3': 'Join One of Our Amazing Campuses'}, page_content='Join One of Our Amazing Campuses'),
#  Document(metadata={'Header 2': 'Services', 'Header 3': 'Join One of Our Amazing Campuses'}, page_content="CUI is vigorously involved in sharing expertise and knowledge from all over the world, with the aim of introducing latest developments in research and best practices within the present education environment.  \nApply Now!  \nUseful Links  \nProspectus  \nA printed booklet advertising a university to potential parents or students or giving details of a share offer for the benefit of investors...  \nRead More  \nUndergraduate Prospectus  \nGraduate Prospectus  \nRankings  \nThese rankings underscore CUI's commitment to providing high-quality education and fostering research excellence, positioning it as a prominent institution...  \nRead More  \nGraduate Output  \nCUI has proudly produced 101,822 graduates since its inception until to-date, which includes 915 PhD graduates as well...  \nRead More  \nTelephone Directory  \nCheck the complete extension list in alphabetical order, search by name, search by extension, and browse by department...  \nRead More  \nTenders  \nCheck out the complete list of advertisements and tenders published by COMSATS University Islamabad....  \nRead More  \nVideos  \nCheck out the complete list of videos related to COMSATS campuses and different departments...  \nRead More  \nDownloads  \nDownload important documents and forms that are helpful for students, faculty, and staff...  \nRead More  \nInternational Students  \nThe preferred career portal for Students & Graduates. Jobs, internships, graduate programmes, and more...  \nRead More  \nEnd testimonial item End testimonial item End testimonial item End testimonial item End testimonial item"),
#  Document(metadata={'Header 2': 'Services', 'Header 3': 'Abuelgasim Ibrahim Idriss Musa'}, page_content='Abuelgasim Ibrahim Idriss Musa'),
#  Document(metadata={'Header 2': 'Services', 'Header 3': 'Abuelgasim Ibrahim Idriss Musa', 'Header 4': 'Sudanese Alumnus'}, page_content='Sudanese Alumnus'),
#  Document(metadata={'Header 2': 'Services', 'Header 3': 'Abuelgasim Ibrahim Idriss Musa', 'Header 4': 'Sudanese Alumnus'}, page_content='CUI is home to students from all over the world; with its great academic programs, supportive faculty, staff and social environment. CUI has given me confidence and taught me to never stop yearning for knowledge. I have become an independent individual and am equipped with skills necessary to be positive and confident to face the social world ahead of me. Thanks CUI and Thanks Pakistan.'),
#  Document(metadata={'Header 2': 'Services', 'Header 3': 'Essa M. I. Elhamalawia'}, page_content='Essa M. I. Elhamalawia'),
#  Document(metadata={'Header 2': 'Services', 'Header 3': 'Essa M. I. Elhamalawia', 'Header 4': 'Palestinian Alumnus'}, page_content='Palestinian Alumnus'),
#  Document(metadata={'Header 2': 'Services', 'Header 3': 'Essa M. I. Elhamalawia', 'Header 4': 'Palestinian Alumnus'}, page_content='Unlike the image portrayed abroad, Pakistan is a very safe place to live and study. Pakistanis love foreigners and have always made me feel at home. I would definitely recommend CUI to other prospective students.'),
#  Document(metadata={'Header 2': 'Services', 'Header 3': 'Haneen Anwar'}, page_content='Haneen Anwar'),
#  Document(metadata={'Header 2': 'Services', 'Header 3': 'Haneen Anwar', 'Header 4': 'Jordanian Alumna'}, page_content='Jordanian Alumna'),
#  Document(metadata={'Header 2': 'Services', 'Header 3': 'Haneen Anwar', 'Header 4': 'Jordanian Alumna'}, page_content='I was in search of a scholarship to fund my education and was privileged to receive the very competitive Association of Commonwealth Universities (ACU) scholarship to study at CUI. This opportunity to studying molecular biology has given me the rare chance of contributing towards research on diseases that will hopefully help improve lives.'),
#  Document(metadata={'Header 2': 'Services', 'Header 3': 'Rumeng HE'}, page_content='Rumeng HE'),
#  Document(metadata={'Header 2': 'Services', 'Header 3': 'Rumeng HE', 'Header 4': 'Chinese Alumna'}, page_content='Chinese Alumna'),
#  Document(metadata={}, page_content='My experience can simply be described as amazing and fulfilling. Studying in such a serene and comfortable environment under the tutelage of professors greatly helped my academic pursuit. Hence, I look forward to a future academic engagement with CUI again.  \nVideo Gallery  \nView More  \nContact Us  \nEnd Contact Section  \nModal content'),
#  Document(metadata={'Header 4': 'Focal Person for Redressal of Public Complaints on Pension Matters":'}, page_content='Focal Person for Redressal of Public Complaints on Pension Matters":'),
#  Document(metadata={}, page_content='Name  \nMr. Muhammad Naeem Akhtar, Deputy Treasurer  \nFax Number:  \n051-9247001  \nClose  \nModal content'),
#  Document(metadata={'Header 4': 'Statutes of the Authorities, Committees, Principal Officers, and Teachers of CUI - 2019'}, page_content='Statutes of the Authorities, Committees, Principal Officers, and Teachers of CUI - 2019'),
#  Document(metadata={'Header 4': 'Statutes of the Authorities, Committees, Principal Officers, and Teachers of CUI - 2019'}, page_content='Constitution, Functions and Powers of the Authorities of the COMSATS University Islamabad Statutes, 2019  \nThe Constitution and Procedure of Representation Committee for Appointments to the Senate COMSATS University Islamabad Statutes, 2019  \nThe Contents of and the Manner of Presenting Annual Report by the Rector before the Senate COMSATS University Islamabad Statutes, 2019  \nConstitution and Procedure of the Emergency Committee COMSATS University Islamabad Statutes, 2019  \nThe Powers and Duties of the Officers and Teachers of COMSATS University Islamabad Statutes, 2019  \nTerms and Conditions of Service and Procedure for the Appointment of the Rector COMSATS University Islamabad Statutes, 2019  \nTerms and Conditions of Service and Procedure for the Appointment of Principal Officers COMSATS University Islamabad Statutes 2019  \nTerms and Conditions of Service and Procedure for the Appointment of the Pro-Rectors COMSATS University Islamabad Statutes 2019  \nTerms and Conditions of Service and Procedure for the Appointment of the Campus Directors COMSATS University Islamabad Statutes 2019  \nElection of Teachers for the Membership of Senate, Syndicate, Academic Council and Representation Committee for Appointments to the Senate COMSATS University Islamabad Statutes, 2019  \nClose  \n<h3>Gp<span>.</span></h3>  \nCOMSATS University Islamabad  \nPark Road, Tarlai Kalan, Islamabad, Pakistan  \n<h4>Useful Links</h4>  \nDirectorate of Information Technology  \nMedalist Criteria for Undergraduate Programs  \nPollens Online  \nSoPs for Degree Verification Process  \nAgreement on Solar Power 300 KW  \n<h4>Our Services</h4>  \nAgreement on SSC  \nEligibility Criteria (Non Faculty)  \nAffiliation and Disaffiliation  \nof Education Institutions  \nRankings  \nQs Stars  \nAwards  \n<h4>Our Services</h4>  \nSearch Faculty & Staff  \nCourse Catalogue  \nSustainable Development Goals 2030  \n<form action="" method="post">\r\n                            <input type="email" name="email">\r\n                            <input type="submit" value="Subscribe">\r\n                        </form>'),
#  Document(metadata={'Header 4': 'Follow Us'}, page_content='Follow Us'),
#  Document(metadata={}, page_content='© Copyright . All Rights Reserved  \nCOMSATS University Islamabad  \nDesigned by  \nITCenter  \nModal content'),
#  Document(metadata={'Header 4': 'Statutes of the Authorities, Committees, Principal Officers, and Teachers of CUI - 2019'}, page_content='Statutes of the Authorities, Committees, Principal Officers, and Teachers of CUI - 2019'),
#  Document(metadata={}, page_content='×  \nCONSTITUTION, FUNCTIONS AND POWERS OF THE AUTHORITIES OF THE COMSATS UNIVERSITY ISLAMABAD STATUTES, 2019  \nTHE CONSTITUTION AND PROCEDURE OF REPRESENTATION COMMITTEE FOR APPOINTMENTS TO THE SENATE COMSATS UNIVERSITY ISLAMABAD STATUTES, 2019  \nTHE CONTENTS OF AND THE MANNER OF PRESENTING ANNUAL REPORT BY THE RECTOR BEFORE THE SENATE COMSATS UNIVERSITY ISLAMABAD STATUTES, 2019  \nCONSTITUTION AND PROCEDURE OF THE EMERGENCY COMMITTEE COMSATS UNIVERSITY ISLAMABAD STATUTES, 2019  \nTHE POWERS AND DUTIES OF THE OFFICERS AND TEACHERS OF COMSATS UNIVERSITY ISLAMABAD STATUTES, 2019  \nTERMS AND CONDITIONS OF SERVICE AND PROCEDURE FOR THE APPOINTMENT OF THE RECTOR COMSATS UNIVERSITY ISLAMABAD STATUTES, 2019  \nTERMS AND CONDITIONS OF SERVICE AND PROCEDURE FOR THE APPOINTMENT OF PRINCIPAL OFFICERS COMSATS UNIVERSITY ISLAMABAD STATUTES 2019  \nTERMS AND CONDITIONS OF SERVICE AND PROCEDURE FOR THE APPOINTMENT OF THE PRO-RECTORS COMSATS UNIVERSITY ISLAMABAD STATUTES 2019  \nTERMS AND CONDITIONS OF SERVICE AND PROCEDURE FOR THE APPOINTMENT OF THE CAMPUS DIRECTORS COMSATS UNIVERSITY ISLAMABAD STATUTES 2019  \nELECTION OF TEACHERS FOR THE MEMBERSHIP OF SENATE, SYNDICATE, ACADEMIC COUNCIL AND REPRESENTATION COMMITTEE FOR APPOINTMENTS TO THE SENATE COMSATS UNIVERSITY ISLAMABAD STATUTES, 2019  \nClose  \nModal content'),
#  Document(metadata={'Header 4': 'Search CUI Website'}, page_content='Search CUI Website'),
#  Document(metadata={}, page_content='×  \nEnter your search criteria in the field below and press "Search" button.  \n(function () {\r\n                                var cx = \'010872107217038431823:oknfqcqq_tm\';\r\n                                var gcse = document.createElement(\'script\');\r\n                                gcse.type = \'text/javascript\';\r\n                                gcse.async = true;\r\n                                gcse.src = \'https://cse.google.com/cse.js?cx=\' + cx;\r\n                                var s = document.getElementsByTagName(\'script\')[0];\r\n                                s.parentNode.insertBefore(gcse, s);\r\n                            })();  \nClose  \njarallax(document.querySelectorAll(\'.jarallax\'), {\r\n            speed: 0.2\r\n        });\r\n        var jarallax = new Jarallax()\r\n        jarallax.addAnimation(\'.jarallax_background\',\r\n            [{ progress: \'0%\', top: \'0\' },\r\n            { progress: \'100%\', top: \'-500px\' }])  \n$(document).ready(function () {\r\n            $("#news-slider").owlCarousel({\r\n                items: 4,\r\n                itemsDesktop: [1199, 3],\r\n                itemsDesktopSmall: [980, 2],\r\n                itemsMobile: [600, 1],\r\n                navigation: true,\r\n                navigationText: ["", ""],\r\n                pagination: true,\r\n                autoPlay: true\r\n            });\r\n\r\n        });\r\n        //# sourceURL=pen.js  \n$(\'.nav-tabs-dropdown\')\r\n            .on("click", ".nav-link:not(\'.active\')", function (event) {\r\n                $(this).closest(\'ul\').removeClass("open");\r\n            })\r\n            .on("click", ".nav-link.active", function (event) {\r\n                $(this).closest(\'ul\').toggleClass("open");\r\n            });  \nwindow.onload = () => {\r\n            $(\'#onload\').modal(\'show\');\r\n        }  \nModal content'),
#  Document(metadata={'Header 3': 'Admission Fall 2025 test Slips'}, page_content='Admission Fall 2025 test Slips'),
#  Document(metadata={'Header 3': 'Admission Fall 2025 test Slips', 'Header 4': 'Admission Fall 2025 Test Slips and Seating Plan , CUI Islamabad Campus'}, page_content='Admission Fall 2025 Test Slips and Seating Plan , CUI Islamabad Campus'),
#  Document(metadata={'Header 3': 'Admission Fall 2025 test Slips', 'Header 4': 'Admission Fall 2025 Test Slips and Seating Plan , CUI Islamabad Campus'}, page_content='Please note that the test will take place physically on campus as per the scheduled date.  \n19 July 2025 test Slips and Seating Plan  \n20 July 2025 test Slips and Seating Plan  \nClose')]
